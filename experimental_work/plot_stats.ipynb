# %%
import numpy as np
import pandas as pd

# %%
x = pd.DataFrame({'classes': [1,2,3], 'test': [4,5,6]})

{'classes':labels, 'pt_means':y, 'pt_mins':temp_errs_mins, 'pt_maxes':temp_errs_maxes, 'ft_means':y_ft, 'ft_mins':temp_errs_ft_mins, 'ft_maxes':temp_errs_ft_maxes}

# %%
plot_save_info = pd.DataFrame([labels, y, temp_errs_mins, temp_errs_maxes, y_ft, temp_errs_ft_mins, temp_errs_ft_maxes], columns=['classes', 'pt_means', 'pt_mins', 'pt_maxes', 'ft_means', 'ft_mins', 'ft_maxes']).to_csv(save_path+'/metric_data/'+pca_path+bias_metric+'/pairs_plot.csv', index=False)
# Out:
#    classes  test
# 0        1     4
# 1        2     5
# 2        3     6

# %%
#!ls ../experiments/coco/resnet50/2022-01-19 16:43:15/metric_data/no_pca/cosine/
        
x = np.load('../experiments/coco/resnet50/2022-01-19 16:43:15/metric_data/no_pca/cosine/self_similarities_comps_ft_averaged.npy', allow_pickle=True)

# %%
x.item()
# Out:
# {'refrig+man vs refrig': [[0.7119346,
#    0.724348,
#    0.71459466,
#    0.73174524,
#    0.7416413,
#    0.7325387,
#    0.74536294,
#    0.7267408,
#    0.6969842,
#    0.7233102,
#    0.72777444,
#    0.71520776,
#    0.7181865,
#    0.73432314,
#    0.712261,
#    0.715428,
#    0.7258722,
#    0.7214388,
#    0.73164624,
#    0.73882,
#    0.71345806,
#    0.7075339,
#    0.74155563,
#    0.7242661,
#    0.7181216,
#    0.71281165,
#    0.7294866,
#    0.7297255,
#    0.7154489,
#    0.72811294,
#    0.7305909,
#    0.6964345,
#    0.72678614,
#    0.7219643,
#    0.7131767,
#    0.716029,
#    0.7296223,
#    0.7252795,
#    0.7003586,
#    0.7123329,
#    0.6863848,
#    0.72348994,
#    0.6928381,
#    0.7103733,
#    0.72014195,
#    0.6868368,
#    0.69852847,
#    0.6957061,
#    0.7377912,
#    0.7249727,
#    0.72712064,
#    0.7437659,
#    0.7233299,
#    0.72925496,
#    0.75230956,
#    0.7634381,
#    0.7046529,
#    0.7193599,
#    0.708695,
#    0.72133183,
# ...

# %%
test = [[1,2], [3,4]]

temp_errs, z = zip(*test)

# %%
x = pd.DataFrame(temp_errs).to_csv('plot.csv', index=False, header=False)

# %%
y = x.to_csv('plot.csv', index=False, header=False)

# %%
y
# Out:
# 'x,y\n1,3.0\n0,\n'
